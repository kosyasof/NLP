# %% [markdown]
# # Компьютерная семантика
#
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * https://www.nltk.org/howto/wordnet.html
# * https://ruwordnet.ru/ru
# * https://habr.com/ru/companies/unistar_digital/articles/687148/
# * https://www.scaler.com/topics/nlp/wordnet-in-nlp/

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1\. Дано описание классов `Sence` и `Synset`. Создайте объект `Synset` на основе файлов из `data/rwn`.

# %%
from dataclasses import dataclass, field

@dataclass
class Sense:
    id: str
    name: str
    lemma: str
    main_word: str
    synt_type: str
    poses: str
    synset_id: str
    meaning: str

@dataclass
class Synset:
    id: str
    ruthes_name: str
    definition: str
    part_of_speech: str
    senses: list[Sense] = field(default_factory=list)
    hyponyms: list["Synset"] = field(default_factory=list, repr=False)
    hypernyms: list["Synset"] = field(default_factory=list, repr=False)

# %%
from bs4 import BeautifulSoup

# %%
with open("synsets.N.xml", encoding='utf8') as fp:
  synsets_bs = BeautifulSoup(fp)

# %%
example_synset = synsets_bs.find("synset")
example_synset
# Out:
# <synset definition="" id="N12658" part_of_speech="N" ruthes_name="КОДИРОВАНИЕ ОТ ЗАВИСИМОСТИ">
# <sense id="115643">МЕДИЦИНСКИЙ КОДИРОВАНИЕ</sense>
# <sense id="115640">КОДИРОВАНИЕ</sense>
# <sense id="115641">КОДИРОВАНИЕ ОТ ЗАВИСИМОСТЬ</sense>
# <sense id="115642">КОДИРОВАНИЕ ЗАВИСИМОСТЬ</sense>
# </synset>

# %%
example_synset.attrs
# Out:
# {'id': 'N12658',
#  'ruthes_name': 'КОДИРОВАНИЕ ОТ ЗАВИСИМОСТИ',
#  'definition': '',
#  'part_of_speech': 'N'}

# %%
synset = Synset(**example_synset.attrs)

# %%
synset.id
# Out:
# 'N12658'

# %%
with open("senses.N.xml", "r", encoding="utf8") as fp:
  senses_bs = BeautifulSoup(fp)

# %%
senses_bs.find('sense')
# Out:
# <sense id="115643" lemma="МЕДИЦИНСКИЙ КОДИРОВАНИЕ" main_word="КОДИРОВАНИЕ" meaning="1" name="МЕДИЦИНСКОЕ КОДИРОВАНИЕ" poses="Adj N" synset_id="N12658" synt_type="NG"></sense>

# %%
senses_list = [
    Sense(**sense.attrs)
    for sense in senses_bs.find_all('sense', synset_id=synset.id)
]

# %% [markdown]
# ## Задачи для самостоятельного решения

# %% [markdown]
# <p class="task" id="1"></p>
#
# 1\. На основе файлов `rwn/synsets.A.xml`, `rwn/synsets.N.xml` и `rwn/synsets.V.xml` создайте словарь `synsets`, где ключом является ID синсета, а значением - объекта класса `Synset`. Поля `senses`, `hyponyms`, `hypernyms` оставьте со значениями по умолчанию. Выведите количество объектов в полученном словаре на экран.

# %%
files = ['synsets.A.xml', 'synsets.N.xml', 'synsets.V.xml']

# %%
synsets = {}
for file_ in files:
  with open(file_, encoding='utf8') as fp:
    synsets_bs = BeautifulSoup(fp)
  for s in synsets_bs.find_all("synset"):
    synset = Synset(**s.attrs)
    synsets[s.attrs['id']] = synset

# %%
import itertools
dict(itertools.islice(synsets.items(), 2))
# Out:
# {'A1': Synset(id='A1', ruthes_name='ПОДПИСКА НА ПЕРИОДИЧЕСКИЕ ИЗДАНИЯ', definition='', part_of_speech='Adj', senses=[]),
#  'A2': Synset(id='A2', ruthes_name='РАВНОМЕРНЫЙ', definition='', part_of_speech='Adj', senses=[])}

# %%
len(synsets)
# Out:
# 49492

# %% [markdown]
# <p class="task" id="2"></p>
#
# 2\. Обновите поле `senses` у объектов в словаре `synsets` на основе файлов `rwn/senses.A.xml`, `rwn/senses.N.xml` и `rwn/senses.V.xml`. Выведите на экран среднее количество синонимов у синсетов.

# %%
files = ['senses.A.xml', 'senses.N.xml', 'senses.V.xml']
for file_ in files:
  with open(file_, encoding='utf8') as fp:
    senses_bs = BeautifulSoup(fp)
  for s in senses_bs.find_all("sense"):
    synsets[s['synset_id']].senses.append(s)

# %%
import itertools
dict(itertools.islice(synsets.items(), 2))
# Out:
# {'A1': Synset(id='A1', ruthes_name='ПОДПИСКА НА ПЕРИОДИЧЕСКИЕ ИЗДАНИЯ', definition='', part_of_speech='Adj', senses=[<sense id="95459" lemma="ПОДПИСНОЙ" main_word="" meaning="2" name="ПОДПИСНОЙ" poses="" synset_id="A1" synt_type="Adj"></sense>]),
#  'A2': Synset(id='A2', ruthes_name='РАВНОМЕРНЫЙ', definition='', part_of_speech='Adj', senses=[<sense id="122916" lemma="РАВНОМЕРНЫЙ" main_word="" meaning="1" name="РАВНОМЕРНЫЙ" poses="" synset_id="A2" synt_type="Adj"></sense>])}

# %%
mean = 0
for v in synsets.values():
  mean += len(v.senses)
mean / len(synsets)
# Out:
# 2.6350925402085186

# %% [markdown]
# <p class="task" id="3"></p>
#
# 3\. Проанализируйте, какие типы отношений представлены в файле `rwn/relation.xml`. Выведите множество типов отношений на экран.
# Обновите поля `hyponyms` и `hypernyms` у объектов в словаре `synsets` на основе файла `rwn/relation.xml`.

# %%
files = ['synset_relations.A.xml', 'synset_relations.N.xml', "synset_relations.V.xml"]

# %%
relation_types = set()
for file_ in files:
  with open(file_, encoding='utf8') as fp:
    relations_bs = BeautifulSoup(fp)
  for r in relations_bs.find_all('relation'):
    relation_types.add(r['name'])
    if r['name'] == "hypernym":
      synsets[r['parent_id']].hypernyms.append(r)
    if r['name'] == "hyponym":
      synsets[r['parent_id']].hyponyms.append(r)

# %%
relation_types
# Out:
# {'POS-synonymy',
#  'antonym',
#  'cause',
#  'domain',
#  'entailment',
#  'hypernym',
#  'hyponym',
#  'instance hypernym',
#  'instance hyponym',
#  'part holonym',
#  'part meronym'}

# %%
synsets['A2'].hypernyms[0]
# Out:
# <relation child_id="A4670" name="hypernym" parent_id="A2"></relation>

# %%
synsets['A2'].hyponyms
# Out:
# [<relation child_id="A8709" name="hyponym" parent_id="A2"></relation>,
#  <relation child_id="A11873" name="hyponym" parent_id="A2"></relation>]

# %% [markdown]
# <p class="task" id="4"></p>
#
# 4\. Напишите функцию `find_by_name`, которая ищет синсеты по вхождению заданного слова в поле `ruthes_name`. При поиске приводите введенное слово к нормальной форме и не учитывайте регистр слов. Функция должна вернуть список, отсортированный по возрастаю значений расстояния Левенштейна между названием синсета и введенным словом. Продемонстрируйте, какие синсеты находятся по слову "собака".

# %%
pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.9 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy2)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 31.1 MB/s eta 0:00:00
# Collecting docopt>=0.6 (from pymorphy2)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=b660eea3aaa5d6abaf1588b777dce76fef8537b812cb0be68c8fd6ab43354860
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
import pymorphy2

morph = pymorphy2.MorphAnalyzer()

# %%
from nltk.metrics.distance import edit_distance

# %%
def find_by_name(name):
  res = []
  name_ = morph.parse(name)[0].normal_form.lower()
  for synset in synsets.values():
    ruthes_name = morph.parse(synset.ruthes_name)[0].normal_form.lower()
    if name in ruthes_name:
      res.append(synset)
  res = sorted(res, key=lambda x: edit_distance(name_, x.ruthes_name))
  return res

# %%
find_by_name('собака')
# Out:
# [Synset(id='A6565', ruthes_name='СОБАКА', definition='хищное млекопитающее семейства псовых', part_of_speech='Adj', senses=[<sense id="4612" lemma="ПСИНЫЙ" main_word="" meaning="1" name="ПСИНЫЙ" poses="" synset_id="A6565" synt_type="Adj"></sense>, <sense id="4946" lemma="ПЕСИЙ" main_word="" meaning="1" name="ПЕСИЙ" poses="" synset_id="A6565" synt_type="Adj"></sense>, <sense id="5115" lemma="СОБАЧИЙ" main_word="" meaning="1" name="СОБАЧИЙ" poses="" synset_id="A6565" synt_type="Adj"></sense>]),
#  Synset(id='N18450', ruthes_name='СОБАКА', definition='хищное млекопитающее семейства псовых', part_of_speech='N', senses=[<sense id="5046" lemma="ПЕСИК" main_word="" meaning="1" name="ПЕСИК" poses="" synset_id="N18450" synt_type="N"></sense>, <sense id="5113" lemma="ПЕС" main_word="" meaning="2" name="ПЕС" poses="" synset_id="N18450" synt_type="N"></sense>, <sense id="5114" lemma="СОБАКА" main_word="" meaning="1" name="СОБАКА" poses="" synset_id="N18450" synt_type="N"></sense>, <sense id="5116" lemma="СОБАЧКА" main_word="" meaning="2" name="СОБАЧКА" poses="" synset_id="N18450" synt_type="N"></sense>, <sense id="5117" lemma="СОБАЧОНКА" main_word="" meaning="1" name="СОБАЧОНКА" poses="" synset_id="N18450" synt_type="N"></sense>, <sense id="5118" lemma="ЧЕТВЕРОНОГИЙ ДРУГ" main_word="ДРУГ" meaning="1" name="ЧЕТВЕРОНОГИЙ ДРУГ" poses="Adj N" synset_id="N18450" synt_type="NG"></sense>, <sense id="4467" lemma="ПСИНА" main_word="" meaning="1" name="ПСИНА" poses="" synset_id="N18450" synt_type="N"></sense>]),
#  Synset(id='N25689', ruthes_name='ПОРОДА СОБАК', definition='', part_of_speech='N', senses=[<sense id="61550" lemma="ПОРОДА СОБАКА" main_word="ПОРОДА" meaning="1" name="ПОРОДА СОБАК" poses="N N" synset_id="N25689" synt_type="NG"></sense>]),
#  Synset(id='A1914', ruthes_name='ЩЕНОК (СОБАКА)', definition='', part_of_speech='Adj', senses=[<sense id="34017" lemma="ЩЕНЯЧИЙ" main_word="" meaning="1" name="ЩЕНЯЧИЙ" poses="" synset_id="A1914" synt_type="Adj"></sense>]),
#  Synset(id='A11469', ruthes_name='ЛАЙКА (СОБАКА)', definition='', part_of_speech='Adj', senses=[<sense id="26482" lemma="ЛАЕЧНЫЙ" main_word="" meaning="1" name="ЛАЕЧНЫЙ" poses="" synset_id="A11469" synt_type="Adj"></sense>]),
#  Synset(id='N18021', ruthes_name='ЩЕНОК (СОБАКА)', definition='', part_of_speech='N', senses=[<sense id="34013" lemma="ЦУЦИК" main_word="" meaning="1" name="ЦУЦИК" poses="" synset_id="N18021" synt_type="N"></sense>, <sense id="34014" lemma="ЩЕНОК" main_word="" meaning="2" name="ЩЕНОК" poses="" synset_id="N18021" synt_type="N"></sense>, <sense id="34015" lemma="КУТЕНОК" main_word="" meaning="1" name="КУТЕНОК" poses="" synset_id="N18021" synt_type="N"></sense>, <sense id="34016" lemma="ЩЕНОЧЕК" main_word="" meaning="1" name="ЩЕНОЧЕК" poses="" synset_id="N18021" synt_type="N"></sense>]),
#  Synset(id='N30243', ruthes_name='ЛАЙКА (СОБАКА)', definition='', part_of_speech='N', senses=[<sense id="26481" lemma="ЛАЙКА" main_word="" meaning="2" name="ЛАЙКА" poses="" synset_id="N30243" synt_type="N"></sense>]),
#  Synset(id='N35039', ruthes_name='ТАКСА (СОБАКА)', definition='порода небольших собак с короткими ногами и длинным туловищем', part_of_speech='N', senses=[<sense id="32529" lemma="ТАКСА" main_word="" meaning="2" name="ТАКСА" poses="" synset_id="N35039" synt_type="N"></sense>]),
#  Synset(id='A333', ruthes_name='БОКСЕР (СОБАКА)', definition='', part_of_speech='Adj', senses=[<sense id="43291" lemma="БОКСЕРСКИЙ" main_word="" meaning="3" name="БОКСЕРСКИЙ" poses="" synset_id="A333" synt_type="Adj"></sense>]),
#  Synset(id='A9227', ruthes_name='КОБЕЛЬ (СОБАКА)', definition='', part_of_speech='Adj', senses=[<sense id="5112" lemma="КОБЕЛИНЫЙ" main_word="" meaning="1" name="КОБЕЛИНЫЙ" poses="" synset_id="A9227" synt_type="Adj"></sense>]),
#  Synset(id='N30406', ruthes_name='КОБЕЛЬ (СОБАКА)', definition='', part_of_speech='N', senses=[<sense id="5110" lemma="ПЕС" main_word="" meaning="3" name="ПЕС" poses="" synset_id="N30406" synt_type="N"></sense>, <sense id="5111" lemma="КОБЕЛЬ" main_word="" meaning="1" name="КОБЕЛЬ" poses="" synset_id="N30406" synt_type="N"></sense>]),
#  Synset(id='N37588', ruthes_name='БОКСЕР (СОБАКА)', definition='', part_of_speech='N', senses=[<sense id="43289" lemma="БОКСЕР" main_word="" meaning="3" name="БОКСЕР" poses="" synset_id="N37588" synt_type="N"></sense>, <sense id="43290" lemma="СОБАКА ПОРОДА БОКСЕР" main_word="СОБАКА" meaning="1" name="СОБАКА ПОРОДЫ БОКСЕР" poses="N N N" synset_id="N37588" synt_type="NG"></sense>]),
#  Synset(id='N24570', ruthes_name='НАТРАВЛИВАНИЕ СОБАК', definition='натравливать собаку (собак) на кого-либо, что-либо', part_of_speech='N', senses=[<sense id="64304" lemma="НАТРАВЛИВАНИЕ" main_word="" meaning="3" name="НАТРАВЛИВАНИЕ" poses="" synset_id="N24570" synt_type="N"></sense>, <sense id="64298" lemma="ТРАВЛЯ СОБАКА" main_word="ТРАВЛЯ" meaning="1" name="ТРАВЛЯ СОБАКАМИ" poses="N N" synset_id="N24570" synt_type="NG"></sense>, <sense id="64305" lemma="НАТРАВЛИВАНИЕ СОБАКА" main_word="НАТРАВЛИВАНИЕ" meaning="1" name="НАТРАВЛИВАНИЕ СОБАК" poses="N N" synset_id="N24570" synt_type="NG"></sense>]),
#  Synset(id='V42844', ruthes_name='НАТРАВЛИВАНИЕ СОБАК', definition='натравливать собаку (собак) на кого-либо, что-либо', part_of_speech='V', senses=[<sense id="64301" lemma="НАТРАВИТЬ СОБАКА" main_word="НАТРАВИТЬ" meaning="1" name="НАТРАВИТЬ СОБАКУ" poses="V N" synset_id="V42844" synt_type="VG"></sense>, <sense id="64302" lemma="НАУСЬКИВАТЬ" main_word="" meaning="3" name="НАУСЬКИВАТЬ" poses="" synset_id="V42844" synt_type="V"></sense>, <sense id="64303" lemma="НАТРАВЛИВАТЬ" main_word="" meaning="3" name="НАТРАВЛИВАТЬ" poses="" synset_id="V42844" synt_type="V"></sense>, <sense id="64299" lemma="НАТРАВИТЬ" main_word="" meaning="3" name="НАТРАВИТЬ" poses="" synset_id="V42844" synt_type="V"></sense>, <sense id="64300" lemma="НАУСЬКАТЬ" main_word="" meaning="3" name="НАУСЬКАТЬ" poses="" synset_id="V42844" synt_type="V"></sense>]),
#  Synset(id='N19934', ruthes_name='БОЙЦОВСКАЯ ПОРОДА СОБАК', definition='', part_of_speech='N', senses=[<sense id="119709" lemma="БОЙЦОВСКИЙ ПОРОДА СОБАКА" main_word="ПОРОДА" meaning="1" name="БОЙЦОВСКАЯ ПОРОДА СОБАК" poses="Adj N N" synset_id="N19934" synt_type="NG"></sense>, <sense id="119708" lemma="БОЙЦОВСКИЙ СОБАКА" main_word="СОБАКА" meaning="1" name="БОЙЦОВСКАЯ СОБАКА" poses="Adj N" synset_id="N19934" synt_type="NG"></sense>, <sense id="119707" lemma="БОЙЦОВСКИЙ ПОРОДА" main_word="ПОРОДА" meaning="1" name="БОЙЦОВСКАЯ ПОРОДА" poses="Adj N" synset_id="N19934" synt_type="NG"></sense>]),
#  Synset(id='N30185', ruthes_name='СОБАЧНИК, ЛЮБИТЕЛЬ СОБАК', definition='', part_of_speech='N', senses=[<sense id="97463" lemma="ДЕРЖАТЕЛЬ СОБАКА" main_word="ДЕРЖАТЕЛЬ" meaning="1" name="ДЕРЖАТЕЛЬ СОБАК" poses="N N" synset_id="N30185" synt_type="NG"></sense>, <sense id="97461" lemma="ЛЮБИТЕЛЬ СОБАКА" main_word="ЛЮБИТЕЛЬ" meaning="1" name="ЛЮБИТЕЛЬ СОБАК" poses="N N" synset_id="N30185" synt_type="NG"></sense>, <sense id="97462" lemma="СОБАЧНИЦА" main_word="" meaning="1" name="СОБАЧНИЦА" poses="" synset_id="N30185" synt_type="N"></sense>, <sense id="97460" lemma="СОБАЧНИК" main_word="" meaning="1" name="СОБАЧНИК" poses="" synset_id="N30185" synt_type="N"></sense>])]

# %% [markdown]
# <p class="task" id="5"></p>
#
# 5\. Для пары слов "собака" и "кошка" найдите ближайший общий родительский синсет и выведите на экран его название. Синсет `A` назовем родительским синсетом синсета `B`, если от `B` можно подняться к `A` в таксономии синсетов, используя отношения гиперонимии. Найдите общий родительский синсет для пары слов "кошка" и "студент" и выведите на экран его название.

# %%
cats = list(
    map(
      lambda x: x.hypernyms,
      find_by_name('кошка')
    )
)
dogs = list(
    map(
      lambda x: x.hypernyms,
      find_by_name('собака')
    )
)

# %%
cats = [item for sublist in cats for item in sublist]
dogs = [item for sublist in dogs for item in sublist]

# %%
hyps = []
for cat in cats:
  for dog in dogs:
    if dog['child_id'] == cat['child_id']:
      hyps.append(dog['child_id'])

# %%
synsets[hyps[0]].ruthes_name
# Out:
# 'ЖИВОТНОЕ'

# %%
students = list(
    map(
      lambda x: x.hypernyms,
      find_by_name('студент')
    )
)

# %%
students = [item for sublist in students for item in sublist]

# %%
hyps = []
while cats != []:
  for cat in cats:
    for student in students:
      if student['child_id'] == cat['child_id']:
        hyps.append(student['child_id'])
  cats = list(map(lambda x: synsets[x['child_id']].hypernyms, cats))
  students = list(map(lambda x: synsets[x['child_id']].hypernyms, students))
  cats = [item for sublist in cats for item in sublist]
  students = [item for sublist in students for item in sublist]

# %%
synsets[hyps[0]].ruthes_name
# Out:
# 'ЖИВОЙ ОРГАНИЗМ'

# %% [markdown]
# <p class="task" id="6"></p>
#
# 6\. Для каждого слова из представленного текста найдите все возможные синонимы. Набор синонимов получите на основе поля `senses` у объектов `Synset`. В случае обнаружения точного совпадения введенного слова хотя бы с одним элементом из `senses`, весь набор `senses` трактуйте как синонимы. При поиске приводите слово к нормальной форме и не учитывайте регистр слов.
#
# Составьте все возможные вариации данного предложения, заменяя слова на найденные синонимы. В случае отсутствия синонимов для какого-то из слов, используйте исходное слово для генерации предложения. Выведите на экран общее количество перефразированных предложений.

# %%
text = "Студент ужаснулся когда увидел задачу"

# %%
def find_synonyms(word):
  synonyms = []
  word = morph.parse(word)[0].normal_form.lower()
  found = find_by_name(word)
  for synset in found:
    for sense in synset.senses:
      if word in sense['name'].lower().split():
        return [s['name'].lower() for s in synset.senses]
  return []

# %%
synonyms = []
for w in text.split():
  if len(find_synonyms(w)) != 0:
    synonyms.append(find_synonyms(w))
  else:
    synonyms.append([w])

# %%
from itertools import product

# %%
for element in itertools.product(*synonyms):
    print(' '.join(element))
# Out:
# студент стынет кровь когда иметь встречу задача
# студент стынет кровь когда видеть задача
# студент стынет кровь когда увидеть задача
# студент стынет кровь когда видаться задача
# студент стынет кровь когда видеться задача
# студент стынет кровь когда повидать задача
# студент стынет кровь когда встретить задача
# студент стынет кровь когда встречать задача
# студент стынет кровь когда свидеться задача
# студент стынет кровь когда увидеться задача
# студент стынет кровь когда пересечься задача
# студент стынет кровь когда встретиться задача
# студент стынет кровь когда встречаться задача
# студент стынет кровь когда пересекаться задача
# студент стынет кровь когда повидаться задача
# студент стынет кровь в жилах когда иметь встречу задача
# студент стынет кровь в жилах когда видеть задача
# студент стынет кровь в жилах когда увидеть задача
# студент стынет кровь в жилах когда видаться задача
# студент стынет кровь в жилах когда видеться задача
# студент стынет кровь в жилах когда повидать задача
# студент стынет кровь в жилах когда встретить задача
# студент стынет кровь в жилах когда встречать задача
# студент стынет кровь в жилах когда свидеться задача
# студент стынет кровь в жилах когда увидеться задача
# студент стынет кровь в жилах когда пересечься задача
# студент стынет кровь в жилах когда встретиться задача
# студент стынет кровь в жилах когда встречаться задача
# студент стынет кровь в жилах когда пересекаться задача
# студент стынет кровь в жилах когда повидаться задача
# студент ужасаться когда иметь встречу задача
# студент ужасаться когда видеть задача
# студент ужасаться когда увидеть задача
# студент ужасаться когда видаться задача
# студент ужасаться когда видеться задача
# студент ужасаться когда повидать задача
# студент ужасаться когда встретить задача
# студент ужасаться когда встречать задача
# студент ужасаться когда свидеться задача
# студент ужасаться когда увидеться задача
# студент ужасаться когда пересечься задача
# студент ужасаться когда встретиться задача
# студент ужасаться когда встречаться задача
# студент ужасаться когда пересекаться задача
# студент ужасаться когда повидаться задача
# студент приходить в ужас когда иметь встречу задача
# студент приходить в ужас когда видеть задача
# студент приходить в ужас когда увидеть задача
# студент приходить в ужас когда видаться задача
# студент приходить в ужас когда видеться задача
# студент приходить в ужас когда повидать задача
# студент приходить в ужас когда встретить задача
# студент приходить в ужас когда встречать задача
# студент приходить в ужас когда свидеться задача
# студент приходить в ужас когда увидеться задача
# студент приходить в ужас когда пересечься задача
# студент приходить в ужас когда встретиться задача
# студент приходить в ужас когда встречаться задача
# студент приходить в ужас когда пересекаться задача
# студент приходить в ужас когда повидаться задача
# студент прийти в ужас когда иметь встречу задача
# студент прийти в ужас когда видеть задача
# студент прийти в ужас когда увидеть задача
# студент прийти в ужас когда видаться задача
# студент прийти в ужас когда видеться задача
# студент прийти в ужас когда повидать задача
# студент прийти в ужас когда встретить задача
# студент прийти в ужас когда встречать задача
# студент прийти в ужас когда свидеться задача
# студент прийти в ужас когда увидеться задача
# студент прийти в ужас когда пересечься задача
# студент прийти в ужас когда встретиться задача
# студент прийти в ужас когда встречаться задача
# студент прийти в ужас когда пересекаться задача
# студент прийти в ужас когда повидаться задача
# студент ужаснуться когда иметь встречу задача
# студент ужаснуться когда видеть задача
# студент ужаснуться когда увидеть задача
# студент ужаснуться когда видаться задача
# студент ужаснуться когда видеться задача
# студент ужаснуться когда повидать задача
# студент ужаснуться когда встретить задача
# студент ужаснуться когда встречать задача
# студент ужаснуться когда свидеться задача
# студент ужаснуться когда увидеться задача
# студент ужаснуться когда пересечься задача
# студент ужаснуться когда встретиться задача
# студент ужаснуться когда встречаться задача
# студент ужаснуться когда пересекаться задача
# студент ужаснуться когда повидаться задача
# студентка стынет кровь когда иметь встречу задача
# студентка стынет кровь когда видеть задача
# студентка стынет кровь когда увидеть задача
# студентка стынет кровь когда видаться задача
# студентка стынет кровь когда видеться задача
# студентка стынет кровь когда повидать задача
# студентка стынет кровь когда встретить задача
# студентка стынет кровь когда встречать задача
# студентка стынет кровь когда свидеться задача
# студентка стынет кровь когда увидеться задача
# студентка стынет кровь когда пересечься задача
# студентка стынет кровь когда встретиться задача
# студентка стынет кровь когда встречаться задача
# студентка стынет кровь когда пересекаться задача
# студентка стынет кровь когда повидаться задача
# студентка стынет кровь в жилах когда иметь встречу задача
# студентка стынет кровь в жилах когда видеть задача
# студентка стынет кровь в жилах когда увидеть задача
# студентка стынет кровь в жилах когда видаться задача
# студентка стынет кровь в жилах когда видеться задача
# студентка стынет кровь в жилах когда повидать задача
# студентка стынет кровь в жилах когда встретить задача
# студентка стынет кровь в жилах когда встречать задача
# студентка стынет кровь в жилах когда свидеться задача
# студентка стынет кровь в жилах когда увидеться задача
# студентка стынет кровь в жилах когда пересечься задача
# студентка стынет кровь в жилах когда встретиться задача
# студентка стынет кровь в жилах когда встречаться задача
# студентка стынет кровь в жилах когда пересекаться задача
# студентка стынет кровь в жилах когда повидаться задача
# студентка ужасаться когда иметь встречу задача
# студентка ужасаться когда видеть задача
# студентка ужасаться когда увидеть задача
# студентка ужасаться когда видаться задача
# студентка ужасаться когда видеться задача
# студентка ужасаться когда повидать задача
# студентка ужасаться когда встретить задача
# студентка ужасаться когда встречать задача
# студентка ужасаться когда свидеться задача
# студентка ужасаться когда увидеться задача
# студентка ужасаться когда пересечься задача
# студентка ужасаться когда встретиться задача
# студентка ужасаться когда встречаться задача
# студентка ужасаться когда пересекаться задача
# студентка ужасаться когда повидаться задача
# студентка приходить в ужас когда иметь встречу задача
# студентка приходить в ужас когда видеть задача
# студентка приходить в ужас когда увидеть задача
# студентка приходить в ужас когда видаться задача
# студентка приходить в ужас когда видеться задача
# студентка приходить в ужас когда повидать задача
# студентка приходить в ужас когда встретить задача
# студентка приходить в ужас когда встречать задача
# студентка приходить в ужас когда свидеться задача
# студентка приходить в ужас когда увидеться задача
# студентка приходить в ужас когда пересечься задача
# студентка приходить в ужас когда встретиться задача
# студентка приходить в ужас когда встречаться задача
# студентка приходить в ужас когда пересекаться задача
# студентка приходить в ужас когда повидаться задача
# студентка прийти в ужас когда иметь встречу задача
# студентка прийти в ужас когда видеть задача
# студентка прийти в ужас когда увидеть задача
# студентка прийти в ужас когда видаться задача
# студентка прийти в ужас когда видеться задача
# студентка прийти в ужас когда повидать задача
# студентка прийти в ужас когда встретить задача
# студентка прийти в ужас когда встречать задача
# студентка прийти в ужас когда свидеться задача
# студентка прийти в ужас когда увидеться задача
# студентка прийти в ужас когда пересечься задача
# студентка прийти в ужас когда встретиться задача
# студентка прийти в ужас когда встречаться задача
# студентка прийти в ужас когда пересекаться задача
# студентка прийти в ужас когда повидаться задача
# студентка ужаснуться когда иметь встречу задача
# студентка ужаснуться когда видеть задача
# студентка ужаснуться когда увидеть задача
# студентка ужаснуться когда видаться задача
# студентка ужаснуться когда видеться задача
# студентка ужаснуться когда повидать задача
# студентка ужаснуться когда встретить задача
# студентка ужаснуться когда встречать задача
# студентка ужаснуться когда свидеться задача
# студентка ужаснуться когда увидеться задача
# студентка ужаснуться когда пересечься задача
# студентка ужаснуться когда встретиться задача
# студентка ужаснуться когда встречаться задача
# студентка ужаснуться когда пересекаться задача
# студентка ужаснуться когда повидаться задача

# %% [markdown]
# ## Обратная связь
# - [x] Хочу получить обратную связь по решению
